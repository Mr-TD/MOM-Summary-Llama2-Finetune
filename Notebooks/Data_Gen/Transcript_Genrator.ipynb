# %%
## import
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import Markdown
import pandas as pd
import random

# %%
## init  & coonfigure
import os
# from dotenv import load_dotenv
# load_dotenv()
GOOGLE_API_KEY='AIzaSyBs9cPdbF3iYSl_mfXGj--Ihdp5LZu13NE'
genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel('gemini-pro')

# %%
## functions
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
## generate topics & create dataframe
def Transcript(topic,no_of_juniors,support):
  #Transcript Genration Prompt
  prompt = f"""
            Generate a detailed transcript for a
            {topic} project daily standup meeting held between manager and {no_of_juniors} junior devloper and 1 {support}.
            The meeting agenda includes discussions on daily task, project updated and road blocks and any other major update.
            The meeting lasts for approximately two hours and involves active participation from all attendees.
            Ensure the transcript captures key points, decisions made, questions raised,
            and any follow-up tasks assigned during the meeting.
            Genrate transcript as mention in below example in transcript only include name and conversation"""
  example = """Example :
            {
              "date": "2024-03-05",
              "time": "09:30 AM",
              "attendess": ["Project Manager", "Developer 1", "Developer 2", "QA Engineer"],
              "transcript": [
                Project Manager: Good morning everyone. Let's kick off our weekly project status meeting. Developer 1, could you please update us on your progress with the feature implementation?
                Developer 1: Sure. I have completed the frontend development for the user authentication module and I'm currently working on integrating it with the backend.
                Developer 2: I've been working on optimizing the database queries for better performance. I have managed to reduce the query execution time by 30%.
                QA Engineer: I've conducted extensive testing on the latest build. So far, I haven't encountered any major issues. However, I'll continue with regression testing to ensure the stability of the system.
                ]
                }
"""
  Prompt = prompt + example

  response = model.generate_content(Prompt)
  trans = response.text
  return trans

# %%
## generate topics & create dataframe
def Transcript(topic,no_of_juniors,support):
  #Transcript Genration Prompt
  prompt = f"""
            Generate a detailed transcript for a
            {topic} project daily standup meeting held between manager and {no_of_juniors} junior devloper and 1 {support}.
            The meeting agenda includes discussions on daily task, project updated and road blocks and any other major update.
            The meeting lasts for approximately two hours and involves active participation from all attendees.
            Ensure the transcript captures key points, decisions made, questions raised,
            and any follow-up tasks assigned during the meeting.
            Genrate transcript as mention in below example in transcript only include name and conversation"""
  example = """Example :
            {
              "date": "date",
              "time": "time",
              "attendess": [],
              "transcript": []
                }
"""
  Prompt = prompt + example

  response = model.generate_content(Prompt)
  trans = response.text
  return trans

# %%
Transcript("devops",'2','Release Manager')

# %%
data = pd.read_csv("Transcript_data.csv")

# %%
data.head()

# %%
data.shape

# %%
data1 = data.iloc[:50]
data2 = data.iloc[50:100]
data3 = data.iloc[100:150]
data4 = data.iloc[150:200]
data5 = data.iloc[200:250]
data6 = data.iloc[250:300]
data7 = data.iloc[300:350]
data8 = data.iloc[350:400]
data9 = data.iloc[400:450]
data10 = data.iloc[450:500]
data11 = data.iloc[500:550]
data12 = data.iloc[550:600]
data13 = data.iloc[600:650]
data14 = data.iloc[650:700]
data15 = data.iloc[700:750]
data16 = data.iloc[750:800]
data17 = data.iloc[800:850]
data18 = data.iloc[850:900]
data19 = data.iloc[900:950]
data20 = data.iloc[950:1000]
data21 = data.iloc[1000:1050]
data22 = data.iloc[1050:]

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data1['Transcript'] = data1.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data1.to_csv("Transcript_Data/Transcript_Data_Batch1.csv",index=False)

# %%
t_data = pd.read_csv("Transcript_Data_Batch1.csv")
t_data.head()

# %%
to_markdown(t_data['Transcript'][0])

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data2['Transcript'] = data2.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data2.to_csv("Transcript_Data/Transcript_Data_Batch2.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data3['Transcript'] = data3.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data3.to_csv("Transcript_Data/Transcript_Data_Batch3.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data4['Transcript'] = data4.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data4.to_csv("Transcript_Data/Transcript_Data_Batch4.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data5['Transcript'] = data5.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data5.to_csv("Transcript_Data/Transcript_Data_Batch5.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data6['Transcript'] = data6.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data6.to_csv("Transcript_Data/Transcript_Data_Batch6.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data7['Transcript'] = data7.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data7.to_csv("Transcript_Data/Transcript_Data_Batch7.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data8['Transcript'] = data8.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data8.to_csv("Transcript_Data/Transcript_Data_Batch8.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data9['Transcript'] = data9.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data9.to_csv("Transcript_Data/Transcript_Data_Batch9.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data10['Transcript'] = data10.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data10.to_csv("Transcript_Data/Transcript_Data_Batch10.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data11['Transcript'] = data11.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data11.to_csv("Transcript_Data/Transcript_Data_Batch11.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data12['Transcript'] = data12.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data12.to_csv("Transcript_Data/Transcript_Data_Batch12.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data13['Transcript'] = data13.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data13.to_csv("Transcript_Data/Transcript_Data_Batch13.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data14['Transcript'] = data14.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data14.to_csv("Transcript_Data/Transcript_Data_Batch14.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data15['Transcript'] = data15.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data15.to_csv("Transcript_Data/Transcript_Data_Batch15.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data16['Transcript'] = data16.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data16.to_csv("Transcript_Data/Transcript_Data_Batch16.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data17['Transcript'] = data17.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data17.to_csv("Transcript_Data/Transcript_Data_Batch17.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data18['Transcript'] = data18.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data18.to_csv("Transcript_Data/Transcript_Data_Batch18.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data19['Transcript'] = data19.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data19.to_csv("Transcript_Data/Transcript_Data_Batch19.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data20['Transcript'] = data20.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data20.to_csv("Transcript_Data/Transcript_Data_Batch20.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data21['Transcript'] = data21.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data21.to_csv("Transcript_Data/Transcript_Data_Batch21.csv",index=False)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
data22['Transcript'] = data22.progress_apply(lambda x: Transcript(x['meeting_topics'],x['attendees'],x['support_attendees']),axis=1)
data22.to_csv("Transcript_Data/Transcript_Data_Batch22.csv",index=False)

# %%
import os

folder_path = "Transcript_Data/"
files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
print(files)

# %%
import pandas as pd
dfs = []
for i in files:
    temp_df = pd.read_csv('Transcript_Data/' + i)
    dfs.append(temp_df)
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df.to_csv("Cleaned_Transcript_Data.csv",index=False)
